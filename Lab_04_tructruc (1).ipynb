# %%
import math
import numpy as np
import pandas as pd
import scipy

# %% [markdown]
# ## Bài tập

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
path = "/content/drive/MyDrive/XLDLTK/bank2.xls"

# %%
from pandas import ExcelFile

# %%
#load data
def load_data(path):
    data = pd.read_excel(path,header = None)
    return data.iloc[1:,:]

# %%
df = load_data('bank2.xls')
df
# Out:
#          0      1      2     3     4      5
# 1    214.8  131.0  131.1   9.0   9.7  141.0
# 2    214.6  129.7  129.7   8.1   9.5  141.7
# 3    214.8  129.7  129.7   8.7   9.6  142.2
# 4    214.8  129.7  129.6   7.5  10.4  142.0
# 5    215.0  129.6  129.7  10.4   7.7  141.8
# ..     ...    ...    ...   ...   ...    ...
# 196  215.0  130.4  130.3   9.9  12.1  139.6
# 197  215.1  130.3  129.9  10.3  11.5  139.7
# 198  214.8  130.3  130.4  10.6  11.1  140.0
# 199  214.7  130.7  130.8  11.2  11.2  139.4
# 200  214.3  129.9  129.9  10.2  11.5  139.6
#
# [200 rows x 6 columns]

# %%
df.shape
# Out:
# (200, 6)

# %%
def matrix_dot(a, b):
    return [[sum(a[i][k] * b[k][j] for k in range(len(a[0]))) for j in range(len(b[0]))] for i in range(len(a))]
    
def matrix_sub(a, b):
    return [[a[i][j] - b[i][j] for j in range(len(a[0]))] for i in range(len(a))]

def matrix_transpose(a):
    return [[a[i][j] for i in range(len(a))] for j in range(len(a[0]))]
def matrix_shape(a):
    return (len(a), len(a[0]))
def matrix_divide(a, b):
    return [[a[i][j] / b for j in range(len(a[0]))] for i in range(len(a))]

# %%
def mean(A):
    return (1/len(A))*sum(A)

# %%
mean_list = []
for i in range(len(df.columns)):
      mean_list.append([mean(df[i])])

# %%
from scipy.linalg import eig

# %%
def sorts(A):
    n = len(A)
    for i in range(n):
      for j in range(0, n-i-1):
        if A[j] > A[j+1]:
            A[j], A[j+1] = A[j+1], A[j]
    return A

# %%
def PCA(path,percent):
    data = load_data(path)
    X = data.values.tolist()
    row, col = df.shape
    mean_list = []
    for i in range(len(data.columns)):
      mean_list.append([mean(data[i])])
    h = [[1] for _ in range(row)]
    h_dot_mu = matrix_dot(h,matrix_transpose(mean_list))
    beta = matrix_sub(X,h_dot_mu)
    cov = matrix_dot(matrix_transpose(beta),beta)
    cov = matrix_divide(cov,row)
    values, vec = eig(cov)
    values = [float(values[i]) for i in range(len(values))]
    vec = vec.tolist()
    idx = [i for i in range(len(values))]
    idx.sort(key=lambda i: values[i], reverse=True)
    values = [values[i] for i in idx]
    vec = matrix_transpose(vec)
    vec = [vec[i] for i in idx]
    A = sum(values)
    sum_v = 0
    for i in range(col):
      sum_v += values[i]/A
      if sum_v >= percent:
        i= i+1
        break
    w = []
    for j in range(i):
      w.append(vec[j])
    return matrix_dot(beta,matrix_transpose(w))

# %%
PCA('bank2.xls',0.9)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15320\3497730482.py:14: ComplexWarning: Casting complex values to real discards the imaginary part
#   values = [float(values[i]) for i in range(len(values))]
# [[-0.5496480988425536, 0.5063730063142362, -0.2758645747369443],
#  [-2.01862924301286, 0.6612636373842906, 0.5019974589330927],
#  [-1.835675461866609, 1.175307338555996, -0.04562915149272684],
#  [-2.494367239566002, -0.11889156338536999, -0.07652521142539737],
#  [-0.7013228189219556, 3.1947666760016467, 0.8387738746790677],
#  [-0.845845967571434, 0.48249401676601633, -0.7702969143874079],
#  [-2.156052598846291, 0.43851664360386156, 0.30721704140603034],
#  [-2.5444184513254253, -0.5952925399344154, 0.26108878211423403],
#  [-1.8017107347386991, -0.1554342567449012, -0.4933923852269683],
#  [-0.35794585049275973, 0.36624770409208113, -0.008309448443710232],
#  [-1.6549095130827776, -0.9502131778601833, -1.35481702523307],
#  [-2.4718746176380426, 0.03657890224774263, -0.340253464403251],
#  [-1.6531296066059236, -0.5333796718439903, -0.4467347541989649],
#  [-2.0478561212041084, -0.4880420592516893, -0.2227852592330507],
#  [-2.1210003161929043, -0.3918320743986504, -0.4086118486930676],
#  [-1.2110265198520689, 1.9346840208582394, 0.8284950219942445],
#  [-1.8031603466489086, 0.478981674461333, 0.12350416609509018],
#  [-1.5388955842876442, 1.576808851119525, 0.2834488771143717],
#  [-2.0885299259338175, -1.141828096840061, -0.4758262740476095],
#  [-1.569832593946633, 0.6608124657308884, -0.23476792963919013],
#  [-1.5643377563609542, 0.3619171803466561, 0.2913510401533389],
#  [-1.7116139826862695, -0.0027743782093684333, -0.5210802107920625],
#  [-1.2980008016690525, -0.21628369691879257, -0.7336546111933764],
#  [-1.3491867246781788, 0.5532190577689919, -0.4398310663183839],
#  [-1.9408546513263956, -0.9017005528454394, 0.05387452991587521],
#  [-1.9948471907356828, -0.19475997174316928, -1.3172939698278547],
#  [-1.6763265780425414, 1.1840392448262458, -0.8147186243500335],
#  [-0.6993669616564742, 1.628202710558531, -0.5123675610955559],
#  [-2.3590482972307525, -0.3899961040187804, -0.3055154453703467],
#  [-2.203952980941256, 1.2744566887489617, 0.6318368002890776],
#  [-1.9555419765105135, -0.23527720401944308, -0.5154449178210123],
#  [-2.071279205250095, 1.4974993083785977, 0.1953396218630521],
#  [-1.5430634964223853, -0.7308874343453334, 0.4505417754030545],
#  [-1.131078422758571, -0.12646174284609485, -0.2400062983763129],
#  [-0.9450082159532875, 0.15611974451489968, -0.8161499150596199],
#  [-0.9116936276139906, 1.2413893159829252, -0.25379187286412064],
#  [-1.7360174251845746, 0.6747900924470583, -0.2864041108017348],
#  [-2.295044629182401, 0.36366547867030313, -0.08706379354797222],
#  [-1.890890030923933, 1.1368897575968466, -0.23227088920781858],
#  [-1.7462097430701538, 0.34501467904424943, 0.9417231105132837],
#  [-1.821127322795011, 1.4989142243757896, 0.23992409251504854],
#  [-0.9147970461646263, 0.376771710123062, 0.4657433567487117],
#  [-1.263651937525318, 1.6904116948190024, 0.5501346696811624],
#  [-0.7381225477814689, 0.5261818838570391, 0.3330141509668635],
#  [-1.5212488235875206, -0.026850432887864262, 0.7240140150147254],
#  [-1.8326793900945753, 0.3986163400134305, 0.26264380563733913],
#  [-1.5942741240215335, 0.19823533615136268, 0.07001004250337939],
#  [-2.5107938058284964, -0.5820685535776553, -0.3975291577359338],
#  [-1.6496171356684308, -0.27853645124757526, 0.4208377922001165],
#  [-2.450316234453909, 0.4988298134664826, 0.47124744108860595],
#  [-2.408200934765094, -0.35782341721885425, 0.7341034241135964],
#  [-0.44324725561291567, 0.9328976240616653, -0.1244196448919489],
#  [-1.4125273992845482, -0.8688903487528715, 0.08708173044140913],
#  [-1.9717623114876437, -0.6695648226320318, -0.6720753568035367],
#  [-1.9548457825957049, 0.10820295543816782, 0.624054522794142],
#  [-1.435362698113269, 1.5065936871006542, 0.047942678194755284],
#  [-0.7587137083456789, 0.4296808497340534, -0.2761793782274808],
#  [-1.3048406979206109, 1.1146790773893493, 0.9815718282914963],
#  [-1.587264689311322, -0.6828926826002858, -0.3884108208681255],
#  [-1.5810348795660123, 0.01015906624053653, -0.06294438052634327],
#  [-1.8151511553381035, 0.4896105767049395, 0.2955260180898872],
#  [-2.2344649231432197, -0.421190239910072, 0.06947594497385723],
#  [-1.8232970879494141, -0.21379876713181734, -0.15373150811940828],
#  [-1.6493054495765072, -0.40578990356004846, 0.001526941560279993],
#  [-1.2666958202135548, 0.08752622186856085, -0.3437035979535161],
#  [-0.6214232467032379, -0.2001056384546243, -0.26266071106457495],
#  [-2.0250052113925765, -0.23938375250053479, 0.6047215803279535],
#  [-1.1989749733032813, 1.150998273324259, 0.47495762787186213],
#  [-1.6510213444416195, 0.789028710060034, -0.004931014235532882],
#  [-0.42421948264744935, -1.6138531498137656, 0.4203940073939163],
#  [-0.9837929842828929, -0.6008330857336909, 0.3234076052032968],
#  [-1.638385652565706, 0.03611741956874048, 0.033739928886312165],
#  [-1.1264427883475547, 0.39491056672973124, 0.11172589299583746],
#  [-2.3184682164059547, -0.29253458945156596, 0.06489311630816275],
#  [-2.7235540374347886, -0.3960184241803427, -0.39842411870854877],
#  [-2.2056676854673096, -0.3724079842513943, 0.2699332276897455],
#  [-1.0255054487432176, 0.4374828752147479, 0.07934018713491131],
#  [-1.9598096956956894, -0.7873456595809523, 0.5340164330451271],
#  [-1.3493123808608298, -0.8354022582483339, -0.19778003581080808],
#  [-2.148622252123557, 0.27345373222410513, 0.259710324395484],
#  [-0.858158876360357, -0.12738377446648783, 0.4354187035041076],
#  [-1.9288031846386622, -0.5497207844912211, 0.5123784187632867],
#  [-1.5123608584219852, 1.1672226419240825, 0.08713752212033654],
#  [-1.6319953370331155, -0.5521056727595156, -0.3097053352290344],
#  [-0.5681405424146917, -0.24426215449105138, -0.9814191131296599],
#  [-1.1603424758596756, 0.5394939936236838, -0.12422495136029121],
#  [-1.5035883032780444, 0.9295375409832385, 0.18277825327166364],
#  [-1.9767834278777374, 0.6001012843504154, -0.12205840532073031],
#  [-2.0156571771509677, -1.0107257338693303, -0.4956184008425485],
#  [-2.062441610490352, 0.07365603903079687, -0.3927337250759666],
#  [-1.616463622631634, 0.8534583825753557, 0.5017555240450743],
#  [-1.4708162643120803, 0.5648135622744244, 0.0732921428175809],
#  [-1.8199307989367106, 0.38762400769318445, 0.424613547234153],
#  [-2.272274163553602, -0.5798701107459636, 0.3272597747757797],
#  [-1.9811874850487494, 0.6101260565228166, 0.06473236146500849],
#  [-1.3206585846126107, 1.129773190059502, -0.1412778383078831],
#  [-0.6172290477379214, 0.3756414541933925, -0.2692862040991316],
#  [-1.6636791630856722, -0.15134841687779998, 0.5085424094806618],
#  [-0.967627195052696, 0.6317073311862252, -0.26267207595048025],
#  [-1.8712728590856482, -0.08419468303541316, 0.5780424671415204],
#  [0.8915916991749601, -0.8826954408482985, -0.19235802629342819],
#  [2.032763978115489, -0.19271171720288383, -0.4191904148221133],
#  [-0.1355670044119233, -1.256738478032777, -0.357044941490252],
#  [0.6435299476474915, -0.04612232388561416, -0.4633934797223233],
#  [2.39959335989088, 0.7679763321349213, -0.26947090161854037],
#  [1.2944424244875847, 0.32527143016023724, -0.07828137343681968],
#  [0.3886127199967516, -1.186894946192658, -0.8410591300112423],
#  [0.8665881375713116, -0.6565880576220919, -0.3269992687252707],
#  [1.3232725353171446, -1.0281064241702622, -0.21618961994034358],
#  [1.1297278596260125, 0.007939094972923527, -0.925412402915385],
#  [-0.10890978017059627, -2.0311876315204205, 0.3059329471983251],
#  [1.3832650311660752, -0.13358522805849316, -0.7867758185881633],
#  [0.5835219417712418, -0.6643938936091507, -1.4789163837218677],
#  [1.9546688022321912, 0.5846084594808008, -0.3354456359964206],
#  [1.4094000282622645, 0.16667468535466584, -0.005178609407598234],
#  [-0.0706680822804665, -1.7041144937270511, 0.4348590839415677],
#  [2.2780232355200063, 1.0652241673015335, -0.14061091403838882],
#  [2.408015610533158, 1.3632184773146114, -0.15773301733910267],
#  [1.6468073871312734, 0.38227546196947393, -0.4040973510878521],
#  [1.5623245941366195, -1.129010900008367, 0.02048206077417647],
#  [1.4142421927253594, -1.0440924685708055, -0.6006807529041595],
#  [2.7277547008569276, 1.4292984658252215, -0.16373688749010462],
#  [2.048336452915475, 0.9951004824525683, -0.9816950950688296],
#  [1.5138168549279754, -0.20844010824526943, -0.44752830363667573],
#  [0.6486800506828154, 0.2544395040283142, 0.09544258291218063],
#  [1.2978914538821873, -0.4992909965963661, -0.15327296449802452],
#  [0.4306657947252216, -0.8247592026890365, -0.6159395213083743],
#  [1.1992856692469942, -0.6240286032006929, -0.9897152298132679],
#  [0.795411392008976, -0.15749256881987675, -0.5726184698493362],
#  [1.0398343641774603, -1.0693501989895484, -0.6579584106275107],
#  [1.3916137615884727, 0.48533555420772334, 0.36779792352285495],
#  [3.072886193474516, 0.6427371887899533, -0.01197660894758068],
#  [1.493881209910297, -0.2225235974892366, -0.5686866751685007],
#  [1.6006828589673594, -0.5629357223076357, -0.48890077780868135],
#  [1.9467953441348045, 0.04829549277807632, 0.1057175196779192],
#  [2.5891257552135376, 0.6140472173448345, -0.22204665177259642],
#  [1.7140754050300144, -0.0935459191640215, 0.2072347060197436],
#  [1.3971493698932527, -1.5593162297092067, 0.7423028960845768],
#  [1.9781028698011784, 0.5813768164532854, -0.21760141754175139],
#  [2.3447315495041736, 1.1679610432525944, 0.20143352076954957],
#  [1.4455938325431823, -1.1013315769685477, -0.22964313223757005],
#  [1.3322290793370652, -0.36919626257661753, 0.6816292127782541],
#  [1.8007732500819085, 0.654142227650989, -0.1475146416320478],
#  [1.436635466395636, 0.026864973109287704, -0.44759060248353305],
#  [2.036537553958075, 1.0045530634145645, 0.8966744432639808],
#  [2.3878560669352655, 1.099504836971699, -0.3310962558133426],
#  [1.9705730147947322, 0.7410387226553865, -0.39933409015044025],
#  [1.504380499439621, -1.7200928947749388, 0.7003564358769447],
#  [1.7204669400077293, -0.050638476283042744, 0.16116035152027186],
#  [1.3117964911563993, -1.3322527523368217, -0.34121488535760836],
#  [2.3047888892493944, 1.088150976928342, -0.13671004271242088],
#  [2.607456906886459, 1.0720099798960092, 0.8854691190038692],
#  [1.3848097720516852, -0.17859429488411482, 0.7236418221489589],
#  [2.652396345383225, 1.2084522143016592, 0.33676868423281664],
#  [2.000003244729648, -0.16088204424490615, -0.16792499423176832],
#  [2.125283895301699, 0.9290833634654285, -0.0819265169030794],
#  [1.332172223563635, -0.41650972057106755, 0.43152397787412056],
#  [2.2246975485394493, 0.4042691292079026, 0.4739696655815301],
#  [3.0471902090700658, 1.5248257961351084, 0.1277920629740279],
#  [0.8624116496926872, -3.000166826298037, 0.9323551982748868],
#  [-0.10020751253665217, -3.164448461585536, 0.6744780273116575],
#  [1.721876203922384, -0.6323457024719267, 1.407266645571037],
#  [2.1757565011567914, 0.7272333982573963, 0.24324163952147365],
#  [2.5681383016630512, 0.3760092591788904, 0.18956065814130052],
#  [1.9406434110709767, 0.8723414304894037, 0.18928624825072632],
#  [1.5045422296301743, -0.8331640901026471, -0.8146344072547431],
#  [1.376204262628305, -0.21729724909039816, 0.4148438070979661],
#  [1.3618416946732264, -1.2166380493836195, 0.41758079213692323],
#  [0.8815340800203249, -1.1913515719305243, -0.1255768945938237],
#  [2.0054079438990757, 0.5814077247760332, -0.05783995191390878],
#  [1.3577595720641265, -2.341764569060965, 1.259361885328337],
#  [2.550579111877924, 1.2633872791658394, 0.16088134539296173],
#  [2.521828547843091, 0.8626244641009178, 0.020412164103359887],
#  [1.6412220505298865, -0.6644171661776791, 0.1681266189267182],
#  [2.012104344461215, 0.7835674839308384, 0.19627284264762124],
#  [2.8410603922721442, 0.6043586324463538, 0.15171570956218494],
#  [2.143681346773851, 0.9437628109553262, 0.22217709267701619],
#  [1.209076775880253, -1.0681968978943488, -0.2915158363886319],
#  [1.7890369132809638, -1.2397177027187376, -0.34392054740304556],
#  [0.9378724904405256, -2.785161762391998, 1.1695313402837892],
#  [2.3807212159295097, 0.37723400504244187, 0.20339214811367223],
#  [0.2420637896711595, -2.23942006832559, 0.6327974424798353],
#  [2.1100712650265105, -0.21893399700549648, -0.24332765292757508],
#  [1.4778636727442658, -0.741299777672368, -0.020000898249303734],
#  [1.682753356905975, -0.06771320962962574, 0.04631549894259934],
#  [2.2830943537048007, 0.5899450995937194, 0.13642929702260453],
#  [0.42644264848425273, -2.80728894417987, 0.6623283382650341],
#  [2.2108683823896538, 0.5492507968680829, 0.5066253736664598],
#  [1.0328141059702667, -1.2496439236160268, -0.08944885378909595],
#  [3.0190143536036413, 2.217746341998918, 0.8734335502461269],
#  [1.4788136533908656, -0.9758637212583525, -0.31362100280635463],
#  [0.7964108096041368, -1.5733816734679218, 0.5703364779288349],
#  [1.958389656764436, -0.1717416530677413, 0.14167272298815103],
#  [1.4446975140828568, -1.1476096432019416, 0.6890414258452815],
#  [2.1578117674200814, 0.8794600572170574, -0.27814302829783305],
#  [1.2491234373120732, -1.159365339257566, -0.6137624752630532],
#  [1.306225741707998, -0.45712169700875876, -0.29497864965360054],
#  [1.3650678100037568, 0.09215055326579949, -0.3897113145891899],
#  [2.2984868840499706, 0.01691873485265205, -0.42998148529799096],
#  [1.2774402191013927, -0.5251366608287324, 0.1506375995567455]]
